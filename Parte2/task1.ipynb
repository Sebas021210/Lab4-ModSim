# %% [markdown]
# # Laboratorio No. 4 - Modelación y Simulación

# %% [markdown]
# Manuel Rodas - 21509 / Jose Santisteban - 21153 / Sebastian Solorzano - 21826

# %% [markdown]
# ### Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# %%
# Parámetros
k = 3  # Parámetro de forma (esperando el 3er carro)
lambdas = [2, 1, 0.5]  # Diferentes valores de lambda
x = np.linspace(0, 10, 1000)  # Valores de tiempo

# %%
# Graficar las distribuciones Gamma
plt.figure(figsize=(10, 6))

for lambda_ in lambdas:
    scale = 1 / lambda_  # El parámetro de escala es 1/lambda
    y = gamma.pdf(x, k, scale=scale)
    plt.plot(x, y, label=f'lambda={lambda_}')

plt.title('Distribución Gamma para Diferentes Valores de Lambda')
plt.xlabel('Tiempo')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()
